# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # read the business csv

# %%
#read the business csv
#df = pd.read_csv('output/business.csv')
business=pd.read_csv('output/business.csv', 
        header=0,
        index_col=["business_id"], 
        usecols=["business_id", "name", "neighborhood",'address',
                'city','state','postal_code','latitude','longitude',
                'stars','review_count','is_open',
                'attributes.RestaurantsPriceRange2','categories',
                 'hours.Monday','hours.Tuesday','hours.Wednesday','hours.Thursday','hours.Friday',
                'hours.Saturday','hours.Sunday'])
#business

# %%
#list(df)
business
# Out:
#                                                       name  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square
# mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs
# v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium
# CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch
# duHFBe87uNSXImQmvBh87Q                             Blimpie
# uUEMrhJiL1a1pCA_I1SU7Q                     Baxter's Cigars
# 2eJEUJIP54tex7T9YOcLSw            Back-Health Chiropractic
# fEylCY3UEH8YJ0Xa7lu6lA                       Auto Bathouse
# kFtuYklkAIlmYw8RZAieGw                 JAB Jewelry Designs
# NqiQdFa93wzUJGo29NbTPQ          Neighborhood Vision Center
# N9BN9ldVl1FNzcB9_eAstw         Red Rock Bowling UYE Part 2
# 6s3z3TlpHOIecuSyPEOp7A                             Sq Cutz
# n33Izvzk_z9_51H6NsQF-A                             Safeway
# m06OZRFTaKKi6U0omfLq4g            Artificial Grass Masters
# SDMRxmcKPNt1AHPBKqO64Q                          Applebee's
# ...

# %% [markdown]
# ---

# %%
#read all unique state column
#list(df['state'].unique())
business.describe()
# Out:
#             latitude      longitude          stars   review_count  \
# count  156638.000000  156638.000000  156639.000000  156639.000000
# mean       38.585033     -92.856485       3.647154      30.238159
# std         5.399871      26.557741       0.977640      96.486631
# min       -36.086009    -142.466650       1.000000       3.000000
# 25%        33.627161    -112.138207       3.000000       4.000000
# 50%        36.142381     -89.523198       3.500000       9.000000
# 75%        43.596845     -79.668760       4.500000      23.000000
# max        89.999314     115.086769       5.000000    6979.000000
#
#              is_open  attributes.RestaurantsPriceRange2
# count  156639.000000                       96355.000000
# mean        0.844375                           1.818712
# std         0.362501                           0.682705
# min         0.000000                           1.000000
# 25%         1.000000                           1.000000
# ...

# %% [markdown]
# ---

# %%
#list(df['categories'].unique())
###### print out all the categories unique
#cat_array=df['categories'].unique()
#for i in range(len(cat_array)):
#    print(i," ")
#    print(cat_array[i])
#    print ("\n")
business.dtypes
# Out:
# name                                  object
# neighborhood                          object
# address                               object
# city                                  object
# state                                 object
# postal_code                           object
# latitude                             float64
# longitude                            float64
# stars                                float64
# review_count                           int64
# is_open                                int64
# attributes.RestaurantsPriceRange2    float64
# categories                            object
# hours.Monday                          object
# hours.Tuesday                         object
# hours.Friday                          object
# hours.Wednesday                       object
# hours.Thursday                        object
# hours.Sunday                          object
# hours.Saturday                        object
# dtype: object

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt

# %%
business['review_count'].max()
# Out:
# 6979

# %%
business.head()
# Out:
#                                                       name neighborhood  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                Richmond Town Square          NaN
# mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs     Eastland
# v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium    Riverdale
# CVtCbSB1zUcUWg-9TNGTuQ                            TRUmatch          NaN
# duHFBe87uNSXImQmvBh87Q                             Blimpie          NaN
#
#                                                     address              city  \
# business_id
# YDf95gJZaq05wvo7hTQbbQ                      691 Richmond Rd  Richmond Heights
# mLwM-h2YhXl2NCgdS84_Bw                       2824 Milton Rd         Charlotte
# v2WhjAB3PIBA8J8VxG3wEg                  337 Danforth Avenue           Toronto
# CVtCbSB1zUcUWg-9TNGTuQ  7702 E Doubletree Ranch Rd, Ste 300        Scottsdale
# duHFBe87uNSXImQmvBh87Q                       4719 N 20Th St           Phoenix
#
# ...

# %%
business.shape #dimension of the sheet
# Out:
# (156639, 20)

# %%
business.columns #look at the column name
# Out:
# Index(['name', 'neighborhood', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes.RestaurantsPriceRange2', 'categories', 'hours.Monday',
#        'hours.Tuesday', 'hours.Friday', 'hours.Wednesday', 'hours.Thursday',
#        'hours.Sunday', 'hours.Saturday'],
#       dtype='object')

# %% [markdown]
# ---

# %%
business['state'].unique() #list out all unique state
# Out:
# array(['OH', 'NC', 'ON', 'AZ', 'PA', 'NV', 'EDH', 'QC', 'WI', 'IL', 'BW',
#        'HLD', 'SC', 'ESX', 'MLN', 'FIF', 'NYK', 'NI', 'ELN', 'WLN', '01',
#        'C', 'NY', 'SCB', 'AL', 'BY', 'RCC', 'ST', 'NTH', 'NLK', '75',
#        'PKN', 'HH', 'TAM', 'CA', 'KHL', 'VT', 'ABE', 'SL', 'DE', 'GLG',
#        'STG', 'ZET', 'XGL', 'WA', 'FLN', 'WHT', 'NE', 'FAL', '3', 'FL'], dtype=object)

# %%
(business['categories'].unique()) #list all unique categories
# Out:
# array(['Shopping,Shopping Centers',
#        'Food,Soul Food,Convenience Stores,Restaurants',
#        'Food,Coffee & Tea', ...,
#        'Food,Taiwanese,Restaurants,Coffee & Tea,Cafes',
#        'Art Galleries,Flowers & Gifts,Event Planning & Services,Framing,Arts & Entertainment,Arts & Crafts,Cards & Stationery,Shopping',
#        'Fashion,Shopping,Food,Department Stores,Mobile Phones,Grocery'], dtype=object)

# %% [markdown]
# # filter out the restaurant

# %%
restaurant=business[business['categories'].str.contains('Food'or'Restaurants', na = False)] 
restaurant.head()
# Out:
#                                                       name       neighborhood  \
# business_id
# mLwM-h2YhXl2NCgdS84_Bw  South Florida Style Chicken & Ribs           Eastland
# v2WhjAB3PIBA8J8VxG3wEg                    The Tea Emporium          Riverdale
# n33Izvzk_z9_51H6NsQF-A                             Safeway                NaN
# 1cLXGXThDYZ5WK_KpBLtkw                         Koko Bakery  Goodrich Kirtland
# reWc1g65PNZnKz_Ub9QKOQ              Milestones Restaurants                NaN
#
#                                     address           city state postal_code  \
# business_id
# mLwM-h2YhXl2NCgdS84_Bw       2824 Milton Rd      Charlotte    NC       28215
# v2WhjAB3PIBA8J8VxG3wEg  337 Danforth Avenue        Toronto    ON     M4K 1N7
# n33Izvzk_z9_51H6NsQF-A   9101 E Baseline Rd           Mesa    AZ       85209
# 1cLXGXThDYZ5WK_KpBLtkw       3710 Payne Ave      Cleveland    OH       44114
# reWc1g65PNZnKz_Ub9QKOQ      30 High Tech Rd  Richmond Hill    ON     L4B 4L9
#
# ...

# %%
groups = restaurant.groupby(['state'])['review_count'].agg({'count'})

# %%
#groups

# %%
restaurant.describe()
# Out:
#            latitude     longitude         stars  review_count       is_open  \
# count  28937.000000  28937.000000  28937.000000   28937.00000  28937.000000
# mean      39.743768    -87.566047      3.545945      36.30366      0.828386
# std        5.746069     28.016634      0.888415     103.23513      0.377051
# min      -34.520401   -119.551325      1.000000       3.00000      0.000000
# 25%       35.150930   -112.013681      3.000000       5.00000      1.000000
# 50%       40.440520    -81.338143      3.500000      11.00000      1.000000
# 75%       43.665535    -79.412310      4.000000      31.00000      1.000000
# max       59.438181     11.769500      5.000000    6417.00000      1.000000
#
#        attributes.RestaurantsPriceRange2
# count                       26855.000000
# mean                            1.545746
# std                             0.622304
# min                             1.000000
# 25%                             1.000000
# ...
